# %%
2+3
# Out:
# 5

# %%
import numpy as np

# %%
import json
with open('../artifacts/kaggle.json','r') as file:
    data = json.load(file)

# %%
data
# Out:
# {'username': 'bumuthuabey', 'key': '6e9347d9d5455099ebde88d336436ecc'}

# %%
! pip install kaggle
# Out:
# Collecting kaggle
#   Downloading kaggle-1.7.4.5-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: bleach in e:\sentiment-analysis-ml-project\.venv\lib\site-packages (from kaggle) (6.2.0)
# Requirement already satisfied: certifi>=14.05.14 in e:\sentiment-analysis-ml-project\.venv\lib\site-packages (from kaggle) (2025.10.5)
# Requirement already satisfied: charset-normalizer in e:\sentiment-analysis-ml-project\.venv\lib\site-packages (from kaggle) (3.4.4)
# Requirement already satisfied: idna in e:\sentiment-analysis-ml-project\.venv\lib\site-packages (from kaggle) (3.11)
# Collecting protobuf (from kaggle)
#   Downloading protobuf-6.33.0-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Requirement already satisfied: python-dateutil>=2.5.3 in e:\sentiment-analysis-ml-project\.venv\lib\site-packages (from kaggle) (2.9.0.post0)
# Collecting python-slugify (from kaggle)
#   Downloading python_slugify-8.0.4-py2.py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: requests in e:\sentiment-analysis-ml-project\.venv\lib\site-packages (from kaggle) (2.32.5)
# Requirement already satisfied: setuptools>=21.0.0 in e:\sentiment-analysis-ml-project\.venv\lib\site-packages (from kaggle) (80.9.0)
# Requirement already satisfied: six>=1.10 in e:\sentiment-analysis-ml-project\.venv\lib\site-packages (from kaggle) (1.17.0)
# Collecting text-unidecode (from kaggle)
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting tqdm (from kaggle)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: urllib3>=1.15.1 in e:\sentiment-analysis-ml-project\.venv\lib\site-packages (from kaggle) (2.5.0)
# Requirement already satisfied: webencodings in e:\sentiment-analysis-ml-project\.venv\lib\site-packages (from kaggle) (0.5.1)
# Requirement already satisfied: colorama in e:\sentiment-analysis-ml-project\.venv\lib\site-packages (from tqdm->kaggle) (0.4.6)
# Downloading kaggle-1.7.4.5-py3-none-any.whl (181 kB)
# Downloading protobuf-6.33.0-cp310-abi3-win_amd64.whl (436 kB)
# Downloading python_slugify-8.0.4-py2.py3-none-any.whl (10 kB)
# Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: text-unidecode, tqdm, python-slugify, protobuf, kaggle
#
#    -------- ------------------------------- 1/5 [tqdm]
#    -------- ------------------------------- 1/5 [tqdm]
#    -------- ------------------------------- 1/5 [tqdm]
#    -------- ------------------------------- 1/5 [tqdm]
#    -------- ------------------------------- 1/5 [tqdm]
#    -------- ------------------------------- 1/5 [tqdm]
#    -------- ------------------------------- 1/5 [tqdm]
#    -------- ------------------------------- 1/5 [tqdm]
#    ---------------- ----------------------- 2/5 [python-slugify]
#    ---------------- ----------------------- 2/5 [python-slugify]
#    ---------------- ----------------------- 2/5 [python-slugify]
#    ------------------------ --------------- 3/5 [protobuf]
#    ------------------------ --------------- 3/5 [protobuf]
#    ------------------------ --------------- 3/5 [protobuf]
#    ------------------------ --------------- 3/5 [protobuf]
#    ------------------------ --------------- 3/5 [protobuf]
#    ------------------------ --------------- 3/5 [protobuf]
#    ------------------------ --------------- 3/5 [protobuf]
#    ------------------------ --------------- 3/5 [protobuf]
#    ------------------------ --------------- 3/5 [protobuf]
#    ------------------------ --------------- 3/5 [protobuf]
#    ------------------------ --------------- 3/5 [protobuf]
#    ------------------------ --------------- 3/5 [protobuf]
#    ------------------------ --------------- 3/5 [protobuf]
#    ------------------------ --------------- 3/5 [protobuf]
#    ------------------------ --------------- 3/5 [protobuf]
#    ------------------------ --------------- 3/5 [protobuf]
#    ------------------------ --------------- 3/5 [protobuf]
#    ------------------------ --------------- 3/5 [protobuf]
#    ------------------------ --------------- 3/5 [protobuf]
#    -------------------------------- ------- 4/5 [kaggle]
#    -------------------------------- ------- 4/5 [kaggle]
#    -------------------------------- ------- 4/5 [kaggle]
#    -------------------------------- ------- 4/5 [kaggle]
#    -------------------------------- ------- 4/5 [kaggle]
#    -------------------------------- ------- 4/5 [kaggle]
#    -------------------------------- ------- 4/5 [kaggle]
#    -------------------------------- ------- 4/5 [kaggle]
#    -------------------------------- ------- 4/5 [kaggle]
#    -------------------------------- ------- 4/5 [kaggle]
#    -------------------------------- ------- 4/5 [kaggle]
#    -------------------------------- ------- 4/5 [kaggle]
#    -------------------------------- ------- 4/5 [kaggle]
#    -------------------------------- ------- 4/5 [kaggle]
#    -------------------------------- ------- 4/5 [kaggle]
#    -------------------------------- ------- 4/5 [kaggle]
#    -------------------------------- ------- 4/5 [kaggle]
#    ---------------------------------------- 5/5 [kaggle]
#
# Successfully installed kaggle-1.7.4.5 protobuf-6.33.0 python-slugify-8.0.4 text-unidecode-1.3 tqdm-4.67.1

# %%
import os
os.environ['KAGGLE_USERNAME'] = data['username']
os.environ['KAGGLE_KEY'] = data['key']

# %%
from kaggle.api.kaggle_api_extended import KaggleApi
api = KaggleApi()
api.authenticate()

# %%
api.dataset_download_files('dineshpiyasamara/sentiment-analysis-dataset',path='../artifacts')
# Out:
# Dataset URL: https://www.kaggle.com/datasets/dineshpiyasamara/sentiment-analysis-dataset

# %%
import zipfile
with zipfile.ZipFile('../artifacts/sentiment-analysis-dataset.zip', 'r') as zip_ref:
    zip_ref.extractall('../artifacts/')
